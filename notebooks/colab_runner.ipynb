# %% [markdown]
# # Colab runner
#
# Thin notebook: clone the repo, install it, run configs, write results to Drive. No logic lives here -- all of it is in the `qrs` package.
#
# Runtime: use a CPU or GPU runtime (the quantum layer runs on the `lightning.qubit` simulator on CPU regardless; a GPU only speeds up the classical backbone).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
REPO_URL = "https://github.com/HariSudhan76/QCNN_Proj.git"
RESULTS_DIR = "/content/drive/MyDrive/qrs_results"
CHECKPOINT_DIR = "/content/drive/MyDrive/qrs_results/checkpoints"

# !git clone $REPO_URL repo
# %cd repo
# !pip install -e .
# Out:
# Cloning into 'repo'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (53/53), done.
# Receiving objects: 100% (74/74), 34.35 KiB | 576.00 KiB/s, done.
# Resolving deltas: 100% (19/19), done.
# remote: Total 74 (delta 19), reused 71 (delta 16), pack-reused 0 (from 0)
# /content/repo/repo/repo
# Obtaining file:///content/repo/repo/repo
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (2.11.0+cpu)
# Requirement already satisfied: pennylane>=0.43 in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (0.45.1)
# Requirement already satisfied: pennylane-lightning in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (2.1.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (6.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (2.2.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (11.3.0)
# Requirement already satisfied: truststore in /usr/local/lib/python3.13/dist-packages (from qrs==0.1.0) (0.10.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (1.16.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (3.6.1)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (0.18.1)
# Requirement already satisfied: autograd<1.9 in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (1.8.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (1.4.4)
# Requirement already satisfied: autoray==0.8.4 in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (0.8.4)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (6.2.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (2.32.4)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (0.14.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (4.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (26.3)
# Requirement already satisfied: diastatic-malt in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (2.15.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.13/dist-packages (from pennylane>=0.43->qrs==0.1.0) (0.7.0)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /usr/local/lib/python3.13/dist-packages (from pennylane-lightning->qrs==0.1.0) (0.3.34.106.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->qrs==0.1.0) (3.32.3)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->qrs==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->qrs==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->qrs==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0->qrs==0.1.0) (2025.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->qrs==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->qrs==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->qrs==0.1.0) (2026.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->qrs==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->qrs==0.1.0) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->qrs==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0->qrs==0.1.0) (1.3.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.13/dist-packages (from diastatic-malt->pennylane>=0.43->qrs==0.1.0) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.0->qrs==0.1.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane>=0.43->qrs==0.1.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane>=0.43->qrs==0.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane>=0.43->qrs==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->pennylane>=0.43->qrs==0.1.0) (2026.7.22)
# Building wheels for collected packages: qrs
#   Building editable for qrs (pyproject.toml) ... done
#   Created wheel for qrs: filename=qrs-0.1.0-0.editable-py3-none-any.whl size=2722 sha256=023e34c9d6057698f4abeebf7a273296ed03756cf6651fe3a560a6d9ce9f8fc5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pnus_4qz/wheels/45/f1/5f/faf8747be9a39801d2099b8a3cb3dfce464d821055b0e870cf
# Successfully built qrs
# Installing collected packages: qrs
#   Attempting uninstall: qrs
#     Found existing installation: qrs 0.1.0
#     Uninstalling qrs-0.1.0:
#       Successfully uninstalled qrs-0.1.0
# Successfully installed qrs-0.1.0

# %%
# %cd /content
# !rm -rf repo
# !git clone https://github.com/HariSudhan76/QCNN_Proj.git repo
# %cd repo
# !pip install -e . --force-reinstall --no-deps
# Out:
# /content
# Cloning into 'repo'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 88 (delta 30), reused 74 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 38.97 KiB | 654.00 KiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/repo
# Obtaining file:///content/repo
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: qrs
#   Building editable for qrs (pyproject.toml) ... done
#   Created wheel for qrs: filename=qrs-0.1.0-0.editable-py3-none-any.whl size=2722 sha256=ce6b15598ec0ab337fd142dbe03ffaab9ca670bc208cf20878b99ede5312966d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-b3j84pgl/wheels/35/82/4e/9a3dc0d2977dddbcc855bd433b2789976c2b7d9642d0ee942d
# Successfully built qrs
# Installing collected packages: qrs
#   Attempting uninstall: qrs
#     Found existing installation: qrs 0.1.0
#     Uninstalling qrs-0.1.0:
#       Successfully uninstalled qrs-0.1.0
# Successfully installed qrs-0.1.0

# %%
import os
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
# Point results_csv and checkpoint_dir at Drive so runs survive the Colab session ending.
# !sed -i "s|results_csv: results/results.csv|results_csv: $RESULTS_DIR/results.csv|" configs/base.yaml
# !sed -i "s|checkpoint_dir: results/checkpoints|checkpoint_dir: $CHECKPOINT_DIR|" configs/base.yaml

# %%
# !python -m qrs.run --config configs/arm_classical.yaml
# Out:
# /content/repo/qrs/data/loaders.py:41: UserWarning: TLS verification of madm.dfki.de failed (missing intermediate cert in its chain -- expected on Linux/Colab). Retrying the EuroSAT download WITHOUT certificate verification.
#   extracted_dir = download_eurosat(config.data_dir)
# [seed=0] f1_weighted=0.9439 accuracy=0.9442 epochs_run=23 train_wallclock_s=5460.1 checkpoint=/content/drive/MyDrive/qrs_results/checkpoints/classical_seed0.pt

# %%
# !python -m qrs.run --config configs/arm_quantum.yaml

# %%
# !python -m qrs.run --config configs/arm_control.yaml

# %%
# !python -m qrs.run --config configs/arm_quantum_attn.yaml

# %%
from qrs.analysis.results import aggregate_results
aggregate_results(f"{RESULTS_DIR}/results.csv")
